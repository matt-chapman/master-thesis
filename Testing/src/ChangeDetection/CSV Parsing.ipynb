# %%
from pandas import DataFrame, read_csv

import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
from tqdm import tqdm, tqdm_pandas

# %matplotlib inline

# %%
chunksize = 10 ** 6
tp = pd.read_csv('~/export.csv', iterator=True, chunksize=chunksize)
pd.concat(tp, ignore_index=True)
# Out:
#                   id                 postingdate         username  \
# 0         6747013160  2017-01-01T00:43:11.000000   elias_del_pozo
# 1         6747013186  2017-01-01T00:43:06.000000    BrightestVoid
# 2         6747013195  2017-01-01T00:43:06.000000     Angeladallau
# 3         6747013870  2017-01-01T00:44:23.000000  alleendoormarie
# 4         6747013883  2017-01-01T00:44:18.000000     WybrenBakker
# 5         6747013887  2017-01-01T00:44:18.000000          puur_ik
# 6         6747013937  2017-01-01T00:05:16.000000       weerzcgrou
# 7         6747013942  2017-01-01T00:04:21.000000             noej
# 8         6747013951  2017-01-01T00:00:51.000000   Opheusdensweer
# 9         6747013915  2017-01-01T00:40:02.000000          _toetie
# 10        6783557873  2017-01-25T15:44:32.000000      vulkaanrots
# 11        6783557747  2017-01-25T15:37:22.000000     Margareth_We
# 12        6779653844  2017-01-23T13:20:28.000000     FrankDePauw1
# ...
